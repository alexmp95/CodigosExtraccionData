# %%
# %matplotlib notebook
#permite ampliar la Img

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_excel("nuevadata.xlsx")
df.head #imprime las columnas
# Out:
# <bound method NDFrame.head of        Unnamed: 0                                           mentions  \
# 0               0  [{'text': {'beginOffset': 213, 'content': 'Loj...
# 1               1  [{'text': {'beginOffset': 713, 'content': 'con...
# 2               2  [{'text': {'beginOffset': 248, 'content': 'Pág...
# 3               3  [{'text': {'beginOffset': 446, 'content': 'dev...
# 4               4  [{'text': {'beginOffset': 12991, 'content': 'D...
# ...           ...                                                ...
# 68813       68813  [{'text': {'beginOffset': 811430, 'content': '...
# 68814       68814  [{'text': {'beginOffset': 811448, 'content': '...
# 68815       68815  [{'text': {'beginOffset': 812161, 'content': '...
# 68816       68816  [{'text': {'beginOffset': 812389, 'content': '...
# 68817       68817  [{'text': {'beginOffset': 813291, 'content': '...
#
#                                                 metadata  \
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# mentions       object
# metadata       object
# name           object
# salience      float64
# type           object
# dtype: object

# %%
df["type"].count()
# Out:
# 68818

# %%
grouped_data = df.groupby('type')

# %%
grouped_data.describe()
# Out:
#               Unnamed: 0                                                \
#                    count          mean           std     min       25%
# type
# ADDRESS            187.0  29720.679144  18699.036385  4284.0  16041.50
# CONSUMER_GOOD      336.0  29226.336310  19868.771601   217.0  13454.25
# DATE              5665.0  32456.387467  19462.507522  3348.0  15538.00
# EVENT              906.0  30892.559603  20138.416136    10.0  13380.75
# LOCATION          1446.0  29269.470954  19533.370050     0.0  13057.00
# NUMBER           43107.0  36448.316909  19604.971598  4415.0  19508.50
# ORGANIZATION      1183.0  29642.126796  19722.216518     7.0  12999.00
# OTHER            11859.0  30697.720803  20024.476047     1.0  13284.50
# PERSON            3120.0  30951.226282  19760.816590     3.0  13518.00
# PHONE_NUMBER       219.0  34798.205479  19774.497235  3322.0  15046.50
# PRICE              436.0  29564.814220  19693.871419  4322.0  16080.75
# ...

# %%
species_counts = df.groupby('type')['type'].count()
print(species_counts)
# Out:
# type
# ADDRESS            187
# CONSUMER_GOOD      336
# DATE              5665
# EVENT              906
# LOCATION          1446
# NUMBER           43107
# ORGANIZATION      1183
# OTHER            11859
# PERSON            3120
# PHONE_NUMBER       219
# PRICE              436
# WORK_OF_ART        354
# Name: type, dtype: int64

# %%
species_counts.plot(kind='bar');
# Out:
# <img src="data:image/png;base64,..." width="711.1111299491228">

# %%
plt.savefig('imgprueba.jpg')
